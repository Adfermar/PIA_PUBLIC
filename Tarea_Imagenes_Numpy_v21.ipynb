# %% [markdown]
# <a href="https://colab.research.google.com/github/Adfermar/PIA/blob/22_11_2022/Tarea_Imagenes_Numpy_v20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ** EJERCICIO NUMPY **
#
#
# ---
#
# Autor:  Afermar
# ---
#
# Fecha última modificación 24/11/2022:
#
#
# ---
#
#
# Versión: 21
#
#
# ---

# %% [markdown]
# # BIBLIOGRAFÍA
#
# > * [Colab Carmelo PIA](https://colab.research.google.com/github/piaizv/Colaboratory/blob/main/create%20images.ipynb#scrollTo=Caq7l9t9f4lC)
#
# Pillow
#
# > * [Tutorial oficial Pillow.org](https://pillow.readthedocs.io/en/stable/handbook/tutorial.html)
#
# > * [Tutorial Pillow](https://thecleverprogrammer.com/2021/08/21/python-imaging-library-pil-tutorial/)
#
# > * [Referencia de Pillow (oficial)](https://pillow.readthedocs.io/en/stable/reference/index.html)
#
#
# Numpy
#
# > * [NumPy quickstart v1.24.dev0 Manual](https://numpy.org/devdocs/user/quickstart.html)
#
#
# Python
#
# > * [Built-in Types in Python](https://docs.python.org/3/library/stdtypes.html#)
#
# > * [Estructuras de datos](https://docs.python.org/es/3/tutorial/datastructures.html#)
#
# > * [Python.org tutorial](https://docs.python.org/3.11/tutorial/index.html)
#
# > * [Funciones Built-in](https://docs.python.org/es/3/library/functions.html)

# %% [markdown]
# # Listado de métodos y atributos útiles de la biblioteca Pillow
#
# *   `np.zeros()`
# *   `Image.fromarray(<array>)`
# *   `np.asarray(<imagen>) `
# *   `Image.open("test.jpg")`
# *   `image.size` >>  `image.mode` >> `image.format`
# *   `image.show()` ¿¿does it work??
# *   `image.crop(start_x, start_y, end_x, end_y)`

# %% [markdown]
# # Operadores básicos Python
# ```
# >
# <
# ==
# !=
# >=
# <=
# ```

# %% [markdown]
# # Enunciado del Ejercicio NumPy
#
# Crea una clase en Python con la que sea cómodo trabajar con imágenes utilizando NumPy.
# Agrégale a la clase los métodos que consideres que puedan resultar útiles a la hora de
# operar con imágenes. Algunos métodos con los que debe contar la clase son:

# %% [markdown]
# ## a)
#  Implementa un método al que se le pase el ancho y el alto de la imagen y el color de la misma. El método debe devolver la imagen creada.

# %% [markdown]
# ## b)
# Implementa un método al que se le pasa el número de elementos horizontales y verticales, así como el ancho y el alto de los elementos horizontales y verticales y que devuelva la imagen creada con un color de fondo diferente para cada elemento.
# Ejemplo: imagen con 8 por 8 elementos del mismo ancho y alto e imagen con 8 por 3 elementos con diferente ancho y alto

# %% [markdown]
# ## c)
# Implementa un método que redimensiona una imagen al ancho y alto especificado, este método deforma la imagen si la relación de aspecto no es la misma.

# %% [markdown]
# ## d)
# Implementa un método que redimensiona una imagen al ancho especificado, sin deformar la imagen.

# %% [markdown]
# ## e)
# Implementa un método que redimensiona una imagen al alto especificado, sin deformar la imagen.

# %% [markdown]
# ## f)
# Implementa un método que devuelva un trozo de una imagen especificando la posición
# horizontal y vertical y el ancho y el alto, si las dimensiones especificadas son superiores a la
# imagen original, debe devolver el recorte disponible.

# %% [markdown]
# ## g)
# Implementa un método que apile dos imágenes horizontal o verticalmente, sin deformarlas. El método debe especificar en sus argumentos qué dimensiones son las que se deben adaptar.

# %% [markdown]
# ## h)
# Implementa un método que apile dos imágenes horizontal o  verticalmente, si las dimensiones de las imágenes no coinciden, debe adaptarlas a la imagen más ancha o más alta, deformándolas si fuera necesario

# %% [markdown]
# ## i)
# Implementa un método que inserte una imagen dentro de otra imagen en la posición horizontal y vertical especificada. Si la imagen que se va a insertar no cabe entera, debe recortarla.
#
# Ejemplo: La primera imagen se inserta en dos imágenes diferentes. En la primera imagen, la posición de inserción especificada no permite insertar la imágen completa. En la segunda imagen, la posición de inserción permite insertar la imagen de forma completa.

# %% [markdown]
# ## j)
# Implementa un método que inserte dentro de una imagen otra imagen en la posición
# horizontal y vertical especificada con el ancho y el alto especificado.
#
# Si la imagen que se va a insertar no cabe entera, debe recortarla.

# %% [markdown]
# ## k)
#
# Implementa un método al que se le pasa el número de elementos horizontales y
# verticales, así como el ancho y el alto de los elementos horizontales y verticales y que devuelva la imagen creada con un color de fondo diferente para cada elemento.
#
# Ejemplo:
#
# Imagen con 8 por 8 elementos del mismo ancho y alto e imagen con 8 por 3 elementos con diferente ancho y alto.

# %%
# Cargamos las bibliotecas necesarias

import sys
from PIL import Image
import numpy as np
from random import randint

# %% [markdown]
# # **DEFINICIÓN DE LA CLASE**
#
#
# ---

# %%
class ImgNumpy:

  def __init__(self, name, W = 1, H = 1, R = 0, G = 0, B = 0):
    # En los métodos para imágenes primero va el ancho y luego el alto
    # En los arrays numpy primer va el alto y luego el ancho
    # np.zeros((height, width))
    self._array = np.zeros((H, W, 3), dtype = np.uint8)
    self._name = name
    self._height = H
    self._width = W
    self._red = R
    self._green = G
    self._blue = B
    for i in range(0, self._array.shape[0]):
      for j in range(0, self._array.shape[1]):
        self._array[i, j] = [R, G, B]
  
  # propiedad imagen: devuelve una imagen creada desde el array
  # equivale a tener una variable de instancia tipo <self._img>
  @property
  def img(self):
      return Image.fromarray(self._array) #self._img 

  # name
  @property
  def name(self):
      return self._name  

  @name.setter
  def name(self, value):
      if value.isalpha():
        self._name = value
      else:
        raise ValueError("Not a valid name.\n \
        Only alphabetic characters allowed.")

  #array
  @property
  def array(self):
    return self._array

  # height
  @property
  def height(self):
      return self._height

  @height.setter
  def height(self, value):
    img = self.img
    img = img.resize((self._width, value))
    self._array = np.asarray(img)
    self._height = value

  # width
  @property
  def width(self):
      return self._width

  @width.setter
  def width(self, value):
    img = self.img
    img = img.resize((value, self._height))
    self._array = np.asarray(img)        
    self._width = value

  # red
  @property
  def red(self):
      return self._red

  @red.setter
  def red(self, value):
        self._red = value
        new_arr = self._array.copy()
        for i in range(0, self._array.shape[0]):
          for j in range(0, self._array.shape[1]):
            # self._array[i, j] = [value, self._green, self._blue]
            new_arr[i, j] = [value, self._green, self._blue]
        self._array = new_arr
  
  # green
  @property
  def green(self):
      return self._green

  @green.setter
  def green(self, value):
        self._green = value
        new_arr = self._array.copy()
        for i in range(0, self._array.shape[0]):
          for j in range(0, self._array.shape[1]):
            new_arr[i, j] = [self._red, value, self._blue]
        self._array = new_arr

  # blue
  @property
  def blue(self):
      return self._blue

  @blue.setter
  def blue(self, value):
        self._blue = value
        new_arr = self._array.copy()
        for i in range(0, self._array.shape[0]):
          for j in range(0, self._array.shape[1]):
            new_arr[i, j] = [self._red, self._green, value]
        self._array = new_arr 

  # About image info
  #-----------------------------------------------------------
  def get_img_format(self):
    img = Image.fromarray(self._array)
    return img.format

  def get_img_format_desc(self):
    img = Image.fromarray(self._array)
    return img.format_description

  def get_img_size(self):
    img = Image.fromarray(self._array)
    return img.size

  def get_img_mode(self):
    img = Image.fromarray(self._array)
    return img.mode

  def get_img_info(self):
    img = Image.fromarray(self._array)
    return (img.format, img.format_description, img.size, img.mode) 
    return print("\nFormat: ", img.format,
              "\nFormat Description: ", img.format_description,
              "\nSize: ", img.size, 
              "\nMode: ", img.mode)

  #-----------------------------------------------------------

  # Devuelve información sobre las
  # variables del objeto
  def print_info(self):
    return print("\nNombre: ", self._name,
                 "\nAncho: ", self._width,
                 "\nAlto: ", self._height, 
                 "\nColor rojo: ", self._red,
                 "\nColor verde: ", self._green,
                 "\nColor azul: ", self._blue)
  
  # Devuelve el shape del array
  def get_ndim(self):
    return self._array.ndim

  # Devuelve el shape del array    
  def get_itemsize(self):
    return self._array.itemsize

  # Devuelve el shape del array
  def get_size(self):
    return self._array.size
  
  # Devuelve el shape del array
  def get_shape(self):
    return self._array.shape

  # Exercise's methods:
  # -------------------

  # c.) Redimensiona la imagen

  def resize(self, width, height):
    # resize(width, height)
    img = self.img
    img = img.resize((width, height))
    self._array = np.asarray(img)        
    self._height = height        
    self._width = width

  # ------------------------------------------------------------------------

  # d.) Redimensiona el ancho dejando el mismo alto
  
  def resize_w(self, new_width):
    # resize(width, height)
    img = Image.fromarray(self._array)
    img = img.resize((new_width, self._height))
    self._array = np.asarray(img)              
    self._width = new_width     

  # ------------------------------------------------------------------------

  # e.) Redimensiona el alto dejando el mismo ancho
 
  def resize_h(self, new_height):
    # resize(width, height)
    img = Image.fromarray(self._array)
    img = img.resize((self._width, new_height))
    self._array = np.asarray(img)              
    self._height = new_height 

  # ------------------------------------------------------------------------

  # f.) Implementa un método que devuelva un trozo de una imagen 
  # especificando la posición horizontal y vertical y el ancho y el alto,
  # si las dimensiones especificadas son superiores a la
  # imagen original, debe devolver el recorte disponible.

  # Opción A
  
  def cropped(self, x_start, y_start, x_end, y_end):
    img = Image.fromarray(self._array)
    cropped = Image.fromarray(self._array)
    if ( 
        ( x_start < x_end ) and
        ( y_start < y_end ) and
        ( x_start + x_end < img.size[0] ) and
        ( y_start + y_end < img.size[1] ) 
      ):
      tuple_params = (x_start, y_start, x_end, y_end)
      cropped = img.crop(tuple_params)
    else: 
      raise ValueError("Incorrect input values")
    return cropped

  # ........................................................................
  
  # f.)
  
  # Opción B
  
  def slice_image(self, X_start=0, Y_start=0, X_end=10, Y_end=10):
    result = Image.fromarray(self._array)
    if  ( X_start < self._width ) and ( Y_start < self._height ):
      if ( X_end + X_start ) < self._width: last_x = X_end + X_start
      else: last_x = self._width
      if ( Y_end + Y_start ) < self._height: last_y = Y_end + Y_start
      else: last_y = self._height
      result = Image.fromarray(self._array[Y_start:last_y, X_start:last_x])
    return result
     
  
  # ------------------------------------------------------------------------

  # g.) Implementa un método que apile dos imágenes horizontal o verticalmente,
  # sin deformarlas. El método debe especificar en sus argumentos qué 
  # dimensiones son las que se deben adaptar. 

  # Opción A

  # This method returns a new image stacked vertically
  # or horizontally according to "position" parameter
  # First parameter: object class ImgNumpy
  # Second parameter: string of value "horizontal" or "vertical"
  def create_stacked_img(self, image, position="vertical"):
    image_result = Image.fromarray(self._array) 
    if position == "vertical":
      image.resize_w(self._width)
      image1 = Image.fromarray(self._array)
      image2 = Image.fromarray(image.array)
      array = np.vstack([image1, image2])
      image_result = Image.fromarray(array)
    elif position == "horizontal":
      image.resize_h(self._height)
      image1 = Image.fromarray(self._array)
      image2 = Image.fromarray(image.array)
      array = np.hstack([image1, image2])
      image_result = Image.fromarray(array)
      pass
    else:
      raise ValueError("Wrong position input") 
    return image_result      
  
  # ........................................................................
  
  # h.)
  # Implementa un método que apile dos imágenes horizontal o  verticalmente, 
  # si las dimensiones de las imágenes no coinciden, debe adaptarlas a la imagen 
  # más ancha o más alta, deformándolas si fuera necesario
  
  def stack_images_deforming(self, img, position = "vertical"):
    result = self.img
    if ( position == "horizontal" ):
      if ( self._height > img.height ): 
        result = self.create_stacked_img(img, "horizontal")
      else:
        result = img.create_stacked_img(self, "horizontal")
    elif ( position == "vertical" ):
      if ( self._width > img.width ): 
        result = self.create_stacked_img(img, "vertical")
      else:
        result = img.create_stacked_img(self, "vertical")    
    else: raise ValueError("Wrong position")
    return result

  # ------------------------------------------------------------------------

  # i.)
  # Implementa un método que inserte una imagen dentro de otra imagen en la 
  # posición horizontal y vertical especificada. 
  # Si la imagen que se va a insertar no cabe entera, debe recortarla.

  # Ejemplo: La primera imagen se inserta en dos imágenes diferentes.
  # En la primera imagen, la posición de inserción especificada no permite 
  # insertar la imágen completa. 
  
  # En la segunda imagen, la posición de inserción permite insertar la 
  # imagen de forma completa.
  def insert_image_force(self, img, x=1, y=1):
    output = self.img
    if ( x >= 0) and  ( y >= 0):
      arr_a = np.copy(self._array)
      arr_b = np.copy(img.array)
      shape_x_a = x + arr_b.shape[0]
      shape_y_a = y + arr_b.shape[1]
      shape_x_b = arr_a.shape[0] - x
      shape_y_b = arr_a.shape[1] - y
      if(shape_x_a > arr_a.shape[0]): shape_x_a = arr_a.shape[0]
      if(shape_y_a > arr_a.shape[1]): shape_y_a = arr_a.shape[1]
      arr_a[x:shape_x_a,y:shape_y_a] = arr_b[0:shape_x_b,0:shape_y_b]
      output = Image.fromarray(arr_a)
    else:
        raise ValueError("Wrong (x, y) inputs")    
    return output

  # ------------------------------------------------------------------------

  # j.)
  # Implementa un método que inserte dentro de una imagen otra imagen
  # en la posición horizontal y vertical especificada con el ancho y el
  # alto especificado. Si la imagen que se vaa insertar no cabe entera,
  # debe recortarla
  def insert_image_redim(self, img, x, y, width, height):
    img_copy = img
    img_copy.width = width
    img_copy.height = height
    return self.insert_image_force(img_copy, x, y)

  # ------------------------------------------------------------------------

  # k.)
  # Implementa un método al que se le pasa el número de elementos horizontales y
  # verticales, así como el ancho y el alto de los elementos horizontales y 
  # verticales y que devuelva la imagen creada con un color de fondo diferente 
  # para cada elemento.

  # Ejemplo: 

  # Imagen con 8 por 8 elementos del mismo ancho y alto e imagen 
  # con 8 por 3 elementos con diferente ancho y alto.
  @staticmethod
  def mosaic(x = 10, y = 10, width = 10, height = 10):
    total_width = x * width
    total_height = y * height
    _data = np.zeros((total_height, total_width, 3), dtype = np.uint8)
    for i in range(0, total_width, width):
        for j in range(0, total_height, height):
            _data[j : j + height, i : i + width] = \
                      (randint(0, 255), randint(0, 255), randint(0, 255))
    return Image.fromarray(_data)

# ------------------------------------------------------------------------

  # Nuevo método: cargar una imagen desde un archivo en nuestro objeto
  # tomamos una imagen. La descomponemos y cambiamos los atributos de 
  # nuestro objeto para que imiten a la imagen.
  def adopt_img_from_file(self, img):
    self._array = np.asarray(img)
    self._height = img.height 
    self._width = img.width
    self._red = 0
    self._green = 0
    self._blue = 0   


# ------------------------------------------------------------------------
# MÉTODO ESTÁTICO
# ------------------------------------------------------------------------
#  Versión estática de 'create_stacked_img'
  
  # This method returns a new image stacked vertically
  # or horizontally according to "position" parameter
  # First and seconds parameters: PIP.Image.Image class
  # Third parameter: string of value "horizontal" or "vertical"
  @staticmethod
  def create_stacked_img_static(img1, img2, position="vertical"):
    image_result = img1
    i = Image.new("RGB", (1,1))
    # Comprobamos que "img1" e "img2" son de la clase 'PIL.Image.Image'
    if (isinstance(img1, (type(i)))) and (isinstance(img2, (type(i)))):
      # Tratamos de unificar el modo de color de las imágenes
      # Sólo trabajamos con el tipo RGB así que intentamos convertir
      # las imágenes de entrada a este formato
      if img1.mode != "RGB":
        try:
          img1 = img1.convert("RGB")
        except ValueError as err:
          print(f"Conversión no permitida {err}, {type(err)}")
        except Exception as err:
          print(f"Error indeterminado {err}, {type(err)}")
          raise
      else: pass
      if img2.mode != "RGB":
        try:
          img2 = img2.convert("RGB")
        except ValueError as err:
          print(f"Conversión no permitida {err}, {type(err)}")
        except Exception as err:
          print(f"Error indeterminado {err}, {type(err)}")
          raise
      else: pass              
      # Comprobación del parámetro de tipo de apilamiento
      if position == "vertical":
        # Se adapta el ancho de la segunda imagen al de la primera
        img2 = img2.resize((img1.width, img2.height))
        image_result = Image.fromarray(np.vstack((np.asarray(img1), np.asarray(img2))))
      elif position == "horizontal":
        # Se adapta el alto de la segunda imagen al de la primera
        img2 = img2.resize((img2.width, img1.height))
        image_result = Image.fromarray(np.hstack((np.asarray(img1), np.asarray(img2))))
      else:
        raise ValueError("Wrong position inputs")
    else:
      raise AttributeError("img1 or img1 are not 'PIL.Image.Image' classes")
    return image_result

# %% [markdown]
# # Comprobación
#
#
# ---

# %% [markdown]
# ## a) Crear una imagen

# %%
# img1 es una instancia de nuestra clase ImgNumpy
img1 = ImgNumpy("Imagen1", 100, 128, 0, 0, 0)
print(img1.array.shape)
print(img1.array.size)
print(img1.array.ndim)
print(img1.array.itemsize)
img1.print_info()
img1.img
# Out:
# (128, 100, 3)
# 38400
# 3
# 1
#
# Nombre:  Imagen1
# Ancho:  100
# Alto:  128
# Color rojo:  0
# Color verde:  0
# Color azul:  0
# <PIL.Image.Image image mode=RGB size=100x128 at 0x7F904C7F2390>

# %% [markdown]
# Obtener propiedades de la imagen asociada a la instancia de clase

# %%
print(  "Formato de la imagen: ", img1.get_img_format(), 
      "\nDescripción: ", img1.get_img_format_desc(), \
      "\nTamaño: ", img1.get_img_size(), 
      "\nTipo de imagen: ", img1.get_img_mode())
# Out:
# Formato de la imagen:  None
# Descripción:  None
# Tamaño:  (100, 128)
# Tipo de imagen:  RGB

# %% [markdown]
# ---

# %% [markdown]
# ## b)  Cambiar alto, ancho y RGB
#
# Implementa un método al que se le pasa el número de elementos horizontales y verticales, así como el ancho y el alto de los elementos horizontales y verticales y que devuelva la imagen creada con un color de fondo diferente para cada elemento.
#
# Ejemplo: imagen con 8 por 8 elementos del mismo ancho y alto e imagen con 8 por 3 elementos con diferente ancho y alto

# %%
# Imagen de origen
img1 = ImgNumpy("Imagen1", 128, 128, 0, 0, 0)
img1.img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F904D0C6650>

# %%
# Imagen destino
img1.width = 100
img1.height = 50
img1.red = 25
img1.blue = 50
img1.green = 75

print(img1.get_img_info())
img1.img
# Out:
# (None, None, (100, 50), 'RGB')
# <PIL.Image.Image image mode=RGB size=100x50 at 0x7F904857FE10>

# %% [markdown]
# ---

# %% [markdown]
# ## c) Cambiar sus dimensiones sin respetar la relación de aspecto
#
# Implementa un método que redimensiona una imagen al ancho y alto especificado, este método deforma la imagen si la relación de aspecto no es la misma.
#
# ``` python
#   # c.) Redimensiona la imagen
#   # resize(width, height)
#   def resize(self, width, height):
#     img = self.img
#     img = img.resize((width, height))
#     self._array = np.asarray(img)
#     self._height = height
#     self._width = width
# ```

# %%
# Imagen de origen
img1 = ImgNumpy("Imagen1", 128, 128, 0, 0, 0)
img1.img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F9048562A50>

# %%
# Imagen destino
img1.resize( 500, 100 )
img1.img
# Out:
# <PIL.Image.Image image mode=RGB size=500x100 at 0x7F9048562AD0>

# %% [markdown]
# ---

# %% [markdown]
# ## d) Cambiar el ancho dejando el mismo alto
#
# ``` python
#   # d.) Redimensiona el ancho de la imagen manteniendo las proporciones
#   # resize(width, height)
#   def resize_w(self, new_width):
#     img = Image.fromarray(self._array)
#     img = img.resize((new_width, self._height))
#     self._array = np.asarray(img)
#     self._width = new_width
# ```

# %%
img1 = ImgNumpy("Imagen1", 128, 128, 0, 0, 0)
img1.img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F904C7DE710>

# %%
img1.resize_w(400)
img1.img
# Out:
# <PIL.Image.Image image mode=RGB size=400x128 at 0x7F904857E950>

# %% [markdown]
# ---

# %% [markdown]
# ## e) Cambiar el alto dejando el mismo ancho
#
# Implementa un método que redimensiona una imagen al alto especificado, sin deformar la imagen.
#
# ``` python
#   def resize_h(self, new_height):
#     # resize(width, height)
#     img = Image.fromarray(self._array)
#     img = img.resize((self._width, new_height))
#     self._array = np.asarray(img)
#     self._height = new_height
# ```

# %%
img1 = ImgNumpy("Imagen1", 128, 128, 0, 0, 0)
img1.img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F904859D4D0>

# %%
img1.resize_h(200)
img1.img
# Out:
# <PIL.Image.Image image mode=RGB size=128x200 at 0x7F904859DDD0>

# %% [markdown]
# ---

# %% [markdown]
# ## f) Recorte
#
# Implementa un método que devuelva un trozo de una imagen especificando la posición horizontal y vertical y el ancho y el alto, si las dimensiones especificadas son superiores a la imagen original, debe devolver el recorte disponible.
#
#  ``` python
#   def cropped(self, x_start, y_start, x_end, y_end):
#     img = Image.fromarray(self._array)
#     cropped = Image.fromarray(self._array)
#     if (
#         ( x_start < x_end ) and
#         ( y_start < y_end ) and
#         ( x_start + x_end < img.size[0] ) and
#         ( y_start + y_end < img.size[1] )
#       ):
#       tuple_params = (x_start, y_start, x_end, y_end)
#       cropped = img.crop(tuple_params)
#     else:
#       raise ValueError("Incorrect input values")
#     return cropped
#  ```

# %%
img1 = ImgNumpy("Imagen1", 128, 128, 0, 255, 0)
img1.img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F90485A7950>

# %%
# Método A
img_cropped = img1.cropped(0, 0, 50, 50)
print(img_cropped.height, img_cropped.width)
img_cropped
# Out:
# 50 50
# <PIL.Image.Image image mode=RGB size=50x50 at 0x7F90485A7190>

# %%
# Método B
params = (0, 0, 50, 50)
img_cropped = img1.slice_image(10, 10, 150, 150)
print(img_cropped.height, img_cropped.width)
img_cropped
# Out:
# 118 118
# <PIL.Image.Image image mode=RGB size=118x118 at 0x7F90484B1590>

# %% [markdown]
# ---

# %% [markdown]
# ## g) Apilar verticalmente u horizontalmente cambiando la anchura y altura
#
# Implementa un método que apile dos imágenes horizontal o verticalmente, sin deformarlas. El método debe especificar en sus argumentos qué dimensiones son las que se deben adaptar.
#
# ``` python
#   def create_stacked_img(self, image, position="vertical"):
#     image_result = Image.fromarray(self._array)
#     if position == "vertical":
#       image.resize_w(self._width)
#       image1 = Image.fromarray(self._array)
#       image2 = Image.fromarray(image.array)
#       array = np.vstack([image1, image2])
#       image_result = Image.fromarray(array)
#     elif position == "horizontal":
#       image.resize_h(self._height)
#       image1 = Image.fromarray(self._array)
#       image2 = Image.fromarray(image.array)
#       array = np.hstack([image1, image2])
#       image_result = Image.fromarray(array)
#       pass
#     else:
#       raise ValueError("Wrong position input")
#     return image_result
# ```

# %% [markdown]
# Vamos a crear dos objetos de nuestra clase ImgNumy.
# Las imágenes se cambiarán de tamaño según un ancho especificado
# y luego se apilarán.

# %%
test1 = ImgNumpy("Imagen1", 200, 100, 0, 0, 0)
test2 = ImgNumpy("Imagen2", 100, 200, 150, 150, 150)

# %%
test1.img
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7F90484A9310>

# %%
test2.img
# Out:
# <PIL.Image.Image image mode=RGB size=100x200 at 0x7F904C7ED590>

# %%
test1.create_stacked_img(test2, "vertical")
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x7F904859DD90>

# %% [markdown]
# ---

# %% [markdown]
# ## h) Apilar verticalmente u horizontalmente cambiando la anchura y altura
#
# Implementa un método que apile dos imágenes horizontal o  verticalmente, si las dimensiones de las imágenes no coinciden, debe adaptarlas a la imagen más ancha o más alta, deformándolas si fuera necesario
#
# ``` python
#   def stack_images_deforming(self, img, position = "vertical"):
#     result = self.img
#     if ( position == "horizontal" ):
#       if ( self._height > img.height ):
#         result = self.create_stacked_img(img, "horizontal")
#       else:
#         result = img.create_stacked_img(self, "horizontal")
#     elif ( position == "vertical" ):
#       if ( self._width > img.width ):
#         result = self.create_stacked_img(img, "vertical")
#       else:
#         result = img.create_stacked_img(self, "vertical")
#     else: raise ValueError("Wrong position")
#     return result
# ```

# %% [markdown]
# Vamos a crear dos objetos de nuestra clase ImgNumy.
# Las imágenes se cambiarán de tamaño según un ancho especificado
# y luego se apilarán.

# %%
test3 = ImgNumpy("Imagen3", 200, 100, 0, 0, 0)
test4 = ImgNumpy("Imagen4", 100, 200, 150, 150, 150)

# %%
test3.img
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7F904857F3D0>

# %%
test4.img
# Out:
# <PIL.Image.Image image mode=RGB size=100x200 at 0x7F904C7F2A50>

# %%
test3.stack_images_deforming(test4, "vertical")
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x7F9048575A90>

# %% [markdown]
# ## i) Insertar imagen a la fuerza
#
# Implementa un método que inserte una imagen dentro de otra imagen en la posición horizontal y vertical especificada. Si la imagen que se va a insertar no cabe entera, debe recortarla.
#
# Ejemplo: La primera imagen se inserta en dos imágenes diferentes. En la primera imagen, la posición de inserción especificada no permite insertar la imágen completa. En la segunda imagen, la posición de inserción permite insertar la imagen de forma completa.
#
# ![i1.jpg](data:image/jpeg;base64,...)
#
# ``` python
#   def insert_image_force(self, img, x=1, y=1):
#     output = self.img
#     if ( x >= 0) and  ( y >= 0):
#       arr_a = np.copy(self._array)
#       arr_b = np.copy(img.array)
#       shape_x_a = x + arr_b.shape[0]
#       shape_y_a = y + arr_b.shape[1]
#       shape_x_b = arr_a.shape[0] - x
#       shape_y_b = arr_a.shape[1] - y
#       if(shape_x_a > arr_a.shape[0]): shape_x_a = arr_a.shape[0]
#       if(shape_y_a > arr_a.shape[1]): shape_y_a = arr_a.shape[1]
#       arr_a[x:shape_x_a,y:shape_y_a] = arr_b[0:shape_x_b,0:shape_y_b]
#       output = Image.fromarray(arr_a)
#     else:
#         raise ValueError("Wrong (x, y) inputs")
#     return output
# ```

# %% [markdown]
# Vamos a crear dos objetos de nuestra clase ImgNumy.
# Las imágenes se cambiarán de tamaño según un ancho especificado
# y luego se apilarán.

# %%
test5 = ImgNumpy("Imagen5", 300, 300, 0, 0, 0)
test6 = ImgNumpy("Imagen6", 100, 50, 150, 150, 150)

# %%
test5.img
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F90484C2690>

# %%
test6.img
# Out:
# <PIL.Image.Image image mode=RGB size=100x50 at 0x7F90484C7190>

# %%
print("Test 5 shape:", test5.get_shape())
print("Test 6 shape:", test6.get_shape())
# Out:
# Test 5 shape: (300, 300, 3)
# Test 6 shape: (50, 100, 3)

# %%
test5.insert_image_force(test6, 200, 250)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F90484B1410>

# %% [markdown]
# ---

# %% [markdown]
# ## j) Insertar imagen redimensionando
#
# Implementa un método que inserte dentro de una imagen otra imagen en la posición
# horizontal y vertical especificada con el ancho y el alto especificado.
#
# Si la imagen que se va a insertar no cabe entera, debe recortarla
#
# ![j1.jpg](data:image/jpeg;base64,...)
#
# ``` python
#   def insert_image_redim(self, img, x, y, width, height):
#     img_copy = img
#     img_copy.width = width
#     img_copy.height = height
#     return self.insert_image_force(img_copy, x, y)
# ```

# %%
test7 = ImgNumpy("Imagen7", 300, 300, 0, 0, 0)
test8 = ImgNumpy("Imagen8", 100, 50, 150, 150, 150)

# %%
test7.img
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F90485A7850>

# %%
test8.img
# Out:
# <PIL.Image.Image image mode=RGB size=100x50 at 0x7F9048575E90>

# %%
print("Test 7 shape:", test7.get_shape())
print("Test 8 shape:", test8.get_shape())
# Out:
# Test 7 shape: (300, 300, 3)
# Test 8 shape: (50, 100, 3)

# %%
test7.insert_image_redim(test8, 200, 120, 150, 150)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F90484B5D50>

# %% [markdown]
# ---

# %% [markdown]
# ## k) Mosaico
#
# Implementa un método al que se le pasa el número de elementos horizontales y
# verticales, así como el ancho y el alto de los elementos horizontales y verticales y que devuelva la imagen creada con un color de fondo diferente para cada elemento.
#
# Ejemplo:
#
# Imagen con 8 por 8 elementos del mismo ancho y alto e imagen con 8 por 3 elementos con diferente ancho y alto.
#
# ![k1.jpg](data:image/jpeg;base64,...)
#
# ``` python
#   def mosaic(x = 10, y = 10, width = 10, height = 10):
#     total_width = x * width
#     total_height = y * height
#     _data = np.zeros((total_height, total_width, 3), dtype = np.uint8)
#     for i in range(0, total_width, width):
#         for j in range(0, total_height, height):
#             _data[j : j + height, i : i + width] = \
#                       (randint(0, 255), randint(0, 255), randint(0, 255))
#     return Image.fromarray(_data)
# ```

# %%
test9 = ImgNumpy("Imagen9", 100, 100, 0, 0, 0)
mosaic = ImgNumpy.mosaic(10,10,20,20)

# %%
mosaic
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F90484D0C10>

# %% [markdown]
# # Banco de pruebas

# %% [markdown]
# ## Nuevo método: adoptar una imagen

# %% [markdown]
# ---

# %% [markdown]
# ## create_stacked_img_static()
#
# Método estático para apliar horizonal o verticalmente dos imágenes (de la clase PIL.Image.Image de la biblioteca Pillow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/PIA/Tarea_17_11_2022_componer_imagenes"

# %%
# %cd $path
# Out:
# /content/drive/MyDrive/PIA/Tarea_17_11_2022_componer_imagenes

# %%
try:
    with open("img1.png", "r") as img1:    
      img1 = Image.open("img1.png", "r")           
except OSError:
    print("error")

# %%
try:
    with open("img2.jpg", "r") as img2:    
      img2 = Image.open("img2.jpg", "r")           
except OSError:
    print("error")

# %%
class_img = ImgNumpy("img1")

# %%
print(img1.size, img1.format, img1.mode)
print(img2.size, img2.format, img2.mode)
# Out:
# (600, 600) PNG RGBA
# (600, 600) JPEG RGB

# %%
print(img1.size, img1.format, img1.mode)
print(img2.size, img2.format, img2.mode)
# Out:
# (600, 600) PNG RGBA
# (600, 600) JPEG RGB

# %%
img1 = img1.resize((100, 70))
img2 = img2.resize((90, 50))

# %%
img1
# Out:
# <PIL.Image.Image image mode=RGBA size=100x70 at 0x7EFC85F73490>

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGB size=90x50 at 0x7EFC89A194D0>

# %%
img_stacked = class_img.create_stacked_img_static(img2, img1,"horizontal")

# %%
img_stacked
# Out:
# <PIL.Image.Image image mode=RGB size=190x50 at 0x7EFC85EDC790>

# %% [markdown]
# ## Otras pruebas

# %%
# alpha = ImgNumpy("Alpha", 300, 300, 50, 50, 50)

# %%
# alpha_arr = alpha.array.copy()

# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# from PIL import Image

# img1 = Image.open("drive/MyDrive/Archivos_Colab/googlelogo.png").convert("RGBA")

# %%
# img2 = Image.open("drive/MyDrive/Archivos_Colab/ojo.png").convert("RGBA")

# %%
# img2

# %%
# array1 = np.asarray(img1).copy()
# array2 = np.asarray(img2).copy()

# %%
# print(array1.shape)
# print(array2.shape)

# %%
# array2[25:array1.shape[0]+25, 25:array1.shape[1]+25] = array1
# result = Image.fromarray(array2)

# %%
# result

# %%
# array1 = np.asarray(img1)
# print(array1.shape)

# array_cropped1 = array1[10:60, 50:200].copy()
# img_cropped1 = Image.fromarray(array_cropped1)

# %%
# img_cropped

# %%
# from PIL import Image
# import numpy as np

# # create a 128 x 128 x 3 array of 8 bit unsigned integers
# data = np.zeros((128, 128, 3), dtype = np.uint8 )

# for i in range(0, data.shape[0]):
#   for j in range(0, data.shape[1]):
#     data[i, j] = [255, 0, 0]

# img = Image.fromarray(data)

# np.save("cuadrado.npy", data)

# img.save("cuadrado.png")
# img.save("cuadrado.gif")

# %%
# arr = np.load("cuadrado.npy")
# img = Image.fromarray(data)
# img

# %%
# print(arr.shape)
# print(test3.get_img_info())
# print(test3.print_info())

# %% [markdown]
# ### Apilar imágenes con un nuevo ancho

# %%
# # Aplilar dos imágenes
# def create_vstack(i1, i2, new_width):
#   image3 = i1.img
#   if ( 1 < new_width ) and ( new_width < 300):
#     i1.redim_width_keep_ratio(new_width)
#     i2.redim_width_keep_ratio(new_width)
#     image1 = Image.fromarray(i1.array)
#     image2 = Image.fromarray(i2.array)
#     array = np.vstack([image1, image2])
#     image3 = Image.fromarray(array)
#   else:
#     raise ValueError("You must introduce a smaller width (1..300")
#   return image3

# %%
# test1 = ImgNumpy("Imagen1", 128, 128, 0, 0, 0)
# test2 = ImgNumpy("Imagen2", 128, 128, 50, 50, 50)

# %% [markdown]
# ---

# %% [markdown]
# ### Apilar imágenes según el ancho o alto más alto (se pueden deformar)

# %%
# Aplilar dos imágenes según el ancho o alto
# más alto deformándolas si es necesario

# def create_vstack_to_max_height_width(i1, i2):
#   max_width = max(i1.width, i2.width)
#   max_height = max(i1.height, i2.height)
#   if ( max_width >= max_height ):
#     #i1.create_vstack(i2, max_width)
#     print("el ancho manda: ", max_width)
#     pass
#   else:
#     print("reconvertir a altura: ", max_height)
#     pass
  
  # image3 = i1.img
  # if ( 1 < new_width ) and ( new_width < 300):
  #   i1.redim_width_keep_ratio(new_width)
  #   i2.redim_width_keep_ratio(new_width)
  #   image1 = Image.fromarray(i1.array)  
  #   image2 = Image.fromarray(i2.array)
  #   array = np.vstack([image1, image2])
  #   image3 = Image.fromarray(array)
  # else:
  #   raise ValueError("You must introduce a smaller width (1..300")
  # return image3

# %%
# test1 = ImgNumpy("Imagen1", 128, 130, 0, 0, 0)
# test2 = ImgNumpy("Imagen2", 140, 128, 50, 50, 50)

# %%
# create_vstack_to_max_height_width(test1, test2)

# %% [markdown]
# ---

# %%
# def new_crop(imagen):
#   x_start = 0
#   y_start = 0
#   x_end = 20
#   y_end = 20

#   array = np.zeros((128, 128, 3), dtype = np.uint8)
#   imagen = Image.fromarray(array)

#   if ( 
#       ( x_start < x_end ) and
#       ( y_start < y_end ) and
#       ( x_start + x_end < imagen.size[0] ) and
#       ( y_start + y_end < imagen.size[1] ) 
#     ): 
#       # cropped = imagen.crop(x_start, y_start, x_end, y_end)
#       cropped = imagen.crop((0, 0, 20, 20))
#   else: 
#     raise ValueError("Incorrect input values")
#   return cropped

# new_crop(img1)

# %% [markdown]
# ---

# %%
# img1.green = 0
# img1.red = 0
# img1.blue = 0

# %%
# img1.print_info()
# img1.img

# %%
# alto = 100
# ancho = 100
# data = np.zeros((alto, ancho, 3), dtype = np.uint8)
# img = Image.fromarray(data)
# img.size
# img

# %%
# alto = 100
# ancho = 100
# alto_nuevo = 50
# ancho_nuevo = 1
# ancho = img.size[0] # img.height
# alto = img.size[1] # img.width
# ancho_nuevo = int((alto_nuevo * ancho) / alto)
# data = np.zeros((alto_nuevo, ancho_nuevo, 3), dtype = np.uint8)
# img = Image.fromarray(data)
# img

# %%
# Dado un nuevo valor para el "height" calcular el "width"
# @staticmethod
# def set_alto(dato, nuevo_alto):
#   img = Image.fromarray(data)
#   ancho = img.width
#   alto = img.height
#   ancho_nuevo = int((alto_nuevo * ancho / alto))
#   img.resize((ancho_nuevo, alto_nuevo))
#   return np.asarray(img)

# %%
# Dado un nuevo valor para el ""width" calcular el "height"
# @staticmethod
# def set_ancho(dato, nuevo_ancho):
#   img = Image.fromarray(data)
#   ancho = img.width
#   alto = img.height
#   alto_nuevo = int((ancho_nuevo * alto / ancho))
#   img.resize((ancho_nuevo, alto_nuevo))
#   return np.asarray(img)

# %% [markdown]
# ---
